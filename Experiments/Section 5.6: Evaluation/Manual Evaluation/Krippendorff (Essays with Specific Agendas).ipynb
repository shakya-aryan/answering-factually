# %% [markdown]
# ## All models

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/alt.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (rows)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.2891577743946636

# %% [markdown]
# ## Krippendorff Base model

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Main Eval Base.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.09432284406764557

# %% [markdown]
# ## Krippendorff Fine-tuned

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Main Eval Fine-Tuned.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.26770760443032793

# %% [markdown]
# ## Krippendorff Fine-Tuned Second Order

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Main Eval Fine-tuned Second.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.1499245180853368

# %% [markdown]
# ## Krippendorff RAG

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Main Eval RAG.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.4073286955704485

# %% [markdown]
# ## Krippendorff RAG Second Order

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Main Eval RAG Second.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.37590080138618165

# %% [markdown]
# ## Factuality over the models

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Base/Factuality.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  -0.07499999999999996

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT/Factuality.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.33510575793184494

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT2/Factuality.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  -0.022203947368421018

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG/Factuality.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.2242446393762182

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG2/Factuality.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.36811594202898545

# %% [markdown]
# ## Coherence over the models

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Base/Coherence.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.24180107526881722

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT/Coherence.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.07766417733523001

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT2/Coherence.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.1351531620553359

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG/Coherence.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.2157403371113048

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG2/Coherence.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.34891927531246425

# %% [markdown]
# ## Organization

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/Base/Organization.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.08593750000000011

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT/Organization.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.3913352272727273

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/FT2/Organization.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.2482114467408586

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG/Organization.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.6862068965517243

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Main Evaluation/RAG2/Organization.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[0]# number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[i, :] == evaluation[j, :] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True), vmin=0, 
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 1)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[0])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.44100000000000006

# %% [markdown]
# ## Persuasiveness over the models

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Persuasiveness Base.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[1]  # number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[:, i] == evaluation[:, j] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True),  
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 0)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[1])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  -0.0106125356125355

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Persuasiveness FT.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[1]  # number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[:, i] == evaluation[:, j] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True),  
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 0)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[1])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  -0.03703703703703698

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as seaborn 
import krippendorff  


data = pd.read_csv('/bigwork/nhwpshaa/pilot experiments/Persuasiveness RAG.csv', header=None)
evaluation = data.to_numpy() #convert data to numpy array
kalpha = krippendorff.alpha(reliability_data=evaluation, level_of_measurement='ordinal')
print("Krippendorff's alpha score: ", kalpha)

annotators = evaluation.shape[1]  # number of annotators (columns)
matrix = np.zeros((annotators, annotators))  # initialization

for i in range(annotators):
    for j in range(i, annotators):
        boolArr = evaluation[:, i] == evaluation[:, j] # check if each value matches and store in a boolean array 
        agreements = np.sum(boolArr)  # count agreements
        matrix[i, j] = agreements
        matrix[j, i] = agreements 


plt.figure(figsize=(11, 9))  
seaborn.heatmap(matrix, annot=True, cmap=seaborn.cubehelix_palette(as_cmap=True),  
            xticklabels=[f'Annotator {i+1}' for i in range(annotators)], 
            yticklabels=[f'Annotator {j+1}' for j in range(annotators)])
plt.title('Annotator Agreement Matrix')  
plt.xlabel('Annotators')  
plt.ylabel('Annotators')  
plt.show()

avg = np.mean(evaluation, axis= 0)
plt.figure(figsize=(10, 8)) 
plt.bar([f'Annotator {i+1}' for i in range(evaluation.shape[1])], avg, color='purple')
plt.title('Average Score by Annotator')
plt.xlabel('Annotator')
plt.ylabel('Average Score')
plt.show()
# Out:
# Krippendorff's alpha score:  0.453030303030303
